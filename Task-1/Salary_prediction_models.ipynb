# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv(r"C:\Users\tejas\Downloads\Salary Prediction of Data Professions.csv")
df
# Out:
#      FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION  \
# 0        TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst
# 1         ANNIE         NaN   F         NaN   01-07-2016       Associate
# 2         OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst
# 3        CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst
# 4          LEON  ABOULAHOUD   M  11-20-2014   01-07-2016         Analyst
# ...         ...         ...  ..         ...          ...             ...
# 2634  KATHERINE      ALSDON   F   6-28-2011   01-07-2016  Senior Manager
# 2635     LOUISE     ALTARAS   F   1-14-2014   01-07-2016         Analyst
# 2636      RENEE      ALVINO   F   1-23-2014   01-07-2016         Analyst
# 2637       TERI   ANASTASIO   F   3-17-2014   01-07-2016         Analyst
# 2638    GREGORY      ABARCA   M   9-18-2014   01-07-2016         Analyst
#
#        AGE  SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  \
# ...

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (2639, 13)

# %%
df.size
# Out:
# 34307

# %%
df.columns
# Out:
# Index(['FIRST NAME', 'LAST NAME', 'SEX', 'DOJ', 'CURRENT DATE', 'DESIGNATION',
#        'AGE', 'SALARY', 'UNIT', 'LEAVES USED', 'LEAVES REMAINING', 'RATINGS',
#        'PAST EXP'],
#       dtype='object')

# %%
df.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3

# %%
df.tail()
# Out:
#      FIRST NAME  LAST NAME SEX        DOJ CURRENT DATE     DESIGNATION   AGE  \
# 2634  KATHERINE     ALSDON   F  6-28-2011   01-07-2016  Senior Manager  36.0
# 2635     LOUISE    ALTARAS   F  1-14-2014   01-07-2016         Analyst  23.0
# 2636      RENEE     ALVINO   F  1-23-2014   01-07-2016         Analyst  21.0
# 2637       TERI  ANASTASIO   F  3-17-2014   01-07-2016         Analyst  24.0
# 2638    GREGORY     ABARCA   M  9-18-2014   01-07-2016         Analyst  24.0
#
#       SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 2634  185977  Management         15.0              15.0      5.0        10
# 2635   45758          IT         17.0              13.0      2.0         0
# 2636   47315         Web         29.0               1.0      5.0         0
# 2637   45172         Web         23.0               7.0      3.0         1
# 2638   49176   Marketing         17.0              13.0      2.0         2

# %%
df.dtypes
# Out:
# FIRST NAME           object
# LAST NAME            object
# SEX                  object
# DOJ                  object
# CURRENT DATE         object
# DESIGNATION          object
# AGE                 float64
# SALARY                int64
# UNIT                 object
# LEAVES USED         float64
# LEAVES REMAINING    float64
# RATINGS             float64
# PAST EXP              int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FIRST NAME        2639 non-null   object
#  1   LAST NAME         2637 non-null   object
#  2   SEX               2639 non-null   object
#  3   DOJ               2638 non-null   object
#  4   CURRENT DATE      2639 non-null   object
#  5   DESIGNATION       2639 non-null   object
#  6   AGE               2636 non-null   float64
#  7   SALARY            2639 non-null   int64
#  8   UNIT              2639 non-null   object
#  9   LEAVES USED       2636 non-null   float64
#  10  LEAVES REMAINING  2637 non-null   float64
#  11  RATINGS           2637 non-null   float64
#  12  PAST EXP          2639 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 268.2+ KB

# %% [markdown]
# #  Data Preprocessing

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (2478, 13)

# %%
df.isnull().sum()
# Out:
# FIRST NAME          0
# LAST NAME           2
# SEX                 0
# DOJ                 1
# CURRENT DATE        0
# DESIGNATION         0
# AGE                 3
# SALARY              0
# UNIT                0
# LEAVES USED         3
# LEAVES REMAINING    2
# RATINGS             2
# PAST EXP            0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.head(50)
# Out:
#    FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE     DESIGNATION   AGE  \
# 0      TOMASA       ARMEN   F   5-18-2014   01-07-2016         Analyst  21.0
# 2       OLIVE        ANCY   F   7-28-2014   01-07-2016         Analyst  21.0
# 3      CHERRY     AQUILAR   F  04-03-2013   01-07-2016         Analyst  22.0
# 6      ELLIOT      AGULAR   M  09-02-2013   01-07-2016         Analyst  22.0
# 8       KATHY       ALSOP   F   6-29-2014   01-07-2016  Senior Analyst  28.0
# 9      LILIAN       APELA   F  11-11-2014   01-07-2016         Analyst  22.0
# 10      BELLE        ARDS   F  03-10-2014   01-07-2016         Analyst  24.0
# 12     WELDON       AIVAO   M  08-01-2013   01-07-2016         Analyst  24.0
# 13       BOYD       AFTON   M   3-22-2013   01-07-2016         Analyst  21.0
# 14       BART   AGUILLERA   M   7-27-2013   01-07-2016         Analyst  24.0
# 16     ALONZO      ADSIDE   M   9-16-2013   01-07-2016         Analyst  25.0
# ...

# %%
df.isnull().sum()
# Out:
# FIRST NAME          0
# LAST NAME           0
# SEX                 0
# DOJ                 0
# CURRENT DATE        0
# DESIGNATION         0
# AGE                 0
# SALARY              0
# UNIT                0
# LEAVES USED         0
# LEAVES REMAINING    0
# RATINGS             0
# PAST EXP            0
# dtype: int64

# %%
df.shape
# Out:
# (2470, 13)

# %%
df.drop(['FIRST NAME'],axis=1,inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\2813062179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['FIRST NAME'],axis=1,inplace=True)

# %%
df.drop(['LAST NAME'],axis=1,inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\933123695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['LAST NAME'],axis=1,inplace=True)

# %% [markdown]
# # Data exploration and visualization

# %%
df.describe()
# Out:
#                AGE         SALARY  LEAVES USED  LEAVES REMAINING      RATINGS  \
# count  2470.000000    2470.000000  2470.000000       2470.000000  2470.000000
# mean     24.725506   58055.764777    22.490688          7.509312     3.482186
# std       3.908838   36776.484770     4.597236          4.597236     1.115217
# min      21.000000   40001.000000    15.000000          0.000000     2.000000
# 25%      22.000000   43401.250000    19.000000          4.000000     2.000000
# 50%      24.000000   46737.500000    22.000000          8.000000     3.000000
# 75%      25.000000   50323.750000    26.000000         11.000000     4.000000
# max      45.000000  388112.000000    30.000000         15.000000     5.000000
#
#           PAST EXP
# count  2470.000000
# mean      1.555870
# std       2.703656
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max      23.000000

# %%
corr = df[['AGE','SALARY','LEAVES USED','LEAVES REMAINING','RATINGS','PAST EXP']].corr()
corr
# Out:
#                        AGE    SALARY  LEAVES USED  LEAVES REMAINING   RATINGS  \
# AGE               1.000000  0.869357     0.004794         -0.004794  0.033534
# SALARY            0.869357  1.000000     0.004596         -0.004596  0.016123
# LEAVES USED       0.004794  0.004596     1.000000         -1.000000  0.004866
# LEAVES REMAINING -0.004794 -0.004596    -1.000000          1.000000 -0.004866
# RATINGS           0.033534  0.016123     0.004866         -0.004866  1.000000
# PAST EXP          0.903694  0.851026     0.003854         -0.003854  0.036397
#
#                   PAST EXP
# AGE               0.903694
# SALARY            0.851026
# LEAVES USED       0.003854
# LEAVES REMAINING -0.003854
# RATINGS           0.036397
# PAST EXP          1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['SEX', 'DOJ', 'CURRENT DATE', 'DESIGNATION', 'AGE', 'SALARY', 'UNIT',
#        'LEAVES USED', 'LEAVES REMAINING', 'RATINGS', 'PAST EXP'],
#       dtype='object')

# %%
df['SEX'].value_counts()
# Out:
# SEX
# F    1255
# M    1215
# Name: count, dtype: int64

# %%
df['SEX'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SEX'>

# %%
df['DESIGNATION'].value_counts()
# Out:
# DESIGNATION
# Analyst           1848
# Senior Analyst     301
# Associate          155
# Manager             79
# Senior Manager      60
# Director            27
# Name: count, dtype: int64

# %%
df['DESIGNATION'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='DESIGNATION'>

# %%
df['UNIT'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='UNIT'>

# %%
df[['SEX','DESIGNATION','UNIT']]
# Out:
#      SEX     DESIGNATION        UNIT
# 0      F         Analyst     Finance
# 2      F         Analyst     Finance
# 3      F         Analyst          IT
# 6      M         Analyst   Marketing
# 8      F  Senior Analyst  Operations
# ...   ..             ...         ...
# 2634   F  Senior Manager  Management
# 2635   F         Analyst          IT
# 2636   F         Analyst         Web
# 2637   F         Analyst         Web
# 2638   M         Analyst   Marketing
#
# [2470 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()

# %%
df['SEX'] = l.fit_transform(df['SEX'])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\784254710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SEX'] = l.fit_transform(df['SEX'])

# %%
df['DESIGNATION'] = l.fit_transform(df['DESIGNATION'])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\2821630118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DESIGNATION'] = l.fit_transform(df['DESIGNATION'])

# %%
df['UNIT'] = l.fit_transform(df['UNIT'])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\1488357940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['UNIT'] = l.fit_transform(df['UNIT'])

# %%
df
# Out:
#       SEX         DOJ CURRENT DATE  DESIGNATION   AGE  SALARY  UNIT  \
# 0       0   5-18-2014   01-07-2016            0  21.0   44570     0
# 2       0   7-28-2014   01-07-2016            0  21.0   40955     0
# 3       0  04-03-2013   01-07-2016            0  22.0   45550     1
# 6       1  09-02-2013   01-07-2016            0  22.0   40339     3
# 8       0   6-29-2014   01-07-2016            4  28.0   63478     4
# ...   ...         ...          ...          ...   ...     ...   ...
# 2634    0   6-28-2011   01-07-2016            5  36.0  185977     2
# 2635    0   1-14-2014   01-07-2016            0  23.0   45758     1
# 2636    0   1-23-2014   01-07-2016            0  21.0   47315     5
# 2637    0   3-17-2014   01-07-2016            0  24.0   45172     5
# 2638    1   9-18-2014   01-07-2016            0  24.0   49176     3
#
#       LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 0            24.0               6.0      2.0         0
# ...

# %%
df.dtypes
# Out:
# SEX                   int32
# DOJ                  object
# CURRENT DATE         object
# DESIGNATION           int32
# AGE                 float64
# SALARY                int64
# UNIT                  int32
# LEAVES USED         float64
# LEAVES REMAINING    float64
# RATINGS             float64
# PAST EXP              int64
# dtype: object

# %%
df['CURRENT DATE'] = pd.to_datetime(df['CURRENT DATE'])
df['DOJ'] = pd.to_datetime(df['DOJ'])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3576144563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CURRENT DATE'] = pd.to_datetime(df['CURRENT DATE'])
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3576144563.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['EXP_YEARS'] = (df['CURRENT DATE']-df['DOJ'])/pd.Timedelta(days=365.25)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\2910161801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXP_YEARS'] = (df['CURRENT DATE']-df['DOJ'])/pd.Timedelta(days=365.25)

# %%
df['EXP_YEARS'] = df['EXP_YEARS'].round(0)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\613484534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXP_YEARS'] = df['EXP_YEARS'].round(0)

# %%
col = ['DOJ','CURRENT DATE']
df.drop(col,axis=1,inplace=True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\155256082.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(col,axis=1,inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()

# %%
df['AGE'] = s.fit_transform(df[['AGE']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\709330711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AGE'] = s.fit_transform(df[['AGE']])

# %%
df['AGE'].plot(kind='box')
# Out:
# <Axes: >

# %%
q1 = df['AGE'].quantile(0.25)
q3 = df['AGE'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers_idx = df[(df['AGE'] < lower_bound) | (df['AGE'] > upper_bound)].index
outliers = df.loc[outliers_idx, 'AGE']

# %%
df.drop(outliers_idx,inplace = True)
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\1769668758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(outliers_idx,inplace = True)

# %%
df['LEAVES USED'] = s.fit_transform(df[['LEAVES USED']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3399216854.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LEAVES USED'] = s.fit_transform(df[['LEAVES USED']])

# %%
df['LEAVES USED'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['LEAVES REMAINING'] = s.fit_transform(df[['LEAVES REMAINING']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\1372753924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LEAVES REMAINING'] = s.fit_transform(df[['LEAVES REMAINING']])

# %%
df['LEAVES REMAINING'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['RATINGS'] = s.fit_transform(df[['RATINGS']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\1331604434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RATINGS'] = s.fit_transform(df[['RATINGS']])

# %%
df['PAST EXP'] = s.fit_transform(df[['PAST EXP']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3004521130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PAST EXP'] = s.fit_transform(df[['PAST EXP']])

# %%
df['SALARY'] = s.fit_transform(np.array(df['SALARY']).reshape(-1,1))
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3342133205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SALARY'] = s.fit_transform(np.array(df['SALARY']).reshape(-1,1))

# %%
df['EXP_YEARS'] = s.fit_transform(df[['EXP_YEARS']])
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_14076\3549686388.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EXP_YEARS'] = s.fit_transform(df[['EXP_YEARS']])

# %%
df
# Out:
#       SEX  DESIGNATION       AGE    SALARY  UNIT  LEAVES USED  \
# 0       0            0 -0.953291 -0.401753     0     0.333311
# 2       0            0 -0.953291 -0.785819     0     0.115108
# 3       0            0 -0.697409 -0.297636     1    -0.103095
# 6       1            0 -0.697409 -0.851264     3    -0.757704
# 8       0            4  0.837885  1.607073     4    -0.539501
# ...   ...          ...       ...       ...   ...          ...
# 2633    0            0 -0.185644 -0.857851     5    -1.194110
# 2635    0            0 -0.441526 -0.275538     1    -1.194110
# 2636    0            0 -0.953291 -0.110119     5     1.424326
# 2637    0            0 -0.185644 -0.337796     5     0.115108
# 2638    1            0 -0.185644  0.087598     3    -1.194110
#
#       LEAVES REMAINING   RATINGS  PAST EXP  EXP_YEARS
# 0            -0.333311 -1.321285 -0.723263  -0.075680
# 2            -0.115108 -0.425334 -0.723263  -1.282208
# 3             0.103095 -0.425334 -0.723263   1.130848
# ...

# %% [markdown]
# # Separating data

# %%
Y = np.array(df['SALARY'])

# %%
Y
# Out:
# array([-0.40175332, -0.78581871, -0.29763601, ..., -0.1101186 ,
#        -0.33779554,  0.08759805])

# %%
X = np.array(df[['SEX','DESIGNATION','AGE','UNIT','LEAVES USED','LEAVES REMAINING','RATINGS','PAST EXP','EXP_YEARS']])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
model = lr.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
r2 = r2_score(y_test,y_pred)
print("R2 score value : ",r2)
rms = root_mean_squared_error(y_test,y_pred)
print("ROOT MEAN SQUARED ERROR : ",rms)
mae = mean_absolute_error(y_test,y_pred)
print("MEAN ABSOLUTE ERROR : ",mae)
mse = mean_squared_error(y_test,y_pred)
print("MEAN SQUARED ERROR : ",mse)
# Out:
# R2 score value :  0.48060815020185765
# ROOT MEAN SQUARED ERROR :  0.7255524489960096
# MEAN ABSOLUTE ERROR :  0.46893284284747466
# MEAN SQUARED ERROR :  0.526426356244107

# %% [markdown]
# # Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor
d_tree = DecisionTreeRegressor(criterion='squared_error',max_depth=200)
d_tree.fit(x_train,y_train)
d_pred = d_tree.predict(x_test)

# %%
d_pred
# Out:
# array([ 5.50707604e-01, -7.47040327e-01, -1.99786983e-01, -2.02377403e-02,
#        -3.80823617e-01, -7.79231701e-01,  6.43310156e-02, -6.18846653e-02,
#        -4.96202598e-01, -3.84051489e-02,  1.65898516e-01, -6.43282349e-02,
#        -3.29296171e-01, -6.50891177e-01, -6.26667965e-01, -7.48102749e-01,
#         1.59099019e-01, -2.90305300e-01, -6.78832863e-01, -3.68074558e-01,
#        -7.16336344e-01,  4.49949433e-02, -7.75406983e-01, -7.86349925e-01,
#        -8.10041926e-01,  1.03003160e-01,  2.47386250e-01, -4.86215835e-01,
#        -2.95192439e-01, -5.40227458e-02,  2.29637246e+00, -7.88793495e-01,
#         5.09445040e-02, -6.69802280e-01,  4.63760913e-02,  5.58316432e-02,
#        -3.97503635e-01, -5.29987603e-01, -6.77279839e-02, -4.20133214e-01,
#        -4.74901046e-01, -6.92431859e-01, -2.81274717e-01, -6.77279839e-02,
#        -9.60415184e-02, -1.99786983e-01, -1.63983377e-01, -4.56574274e-01,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
r2 =r2_score(y_test,d_pred)
print("R2 SCORE : ",r2)
rms = root_mean_squared_error(y_test,d_pred)
print("ROOT MEAN SQUARED ERROR : ",rms)
mae = mean_absolute_error(y_test,d_pred)
print("MEAN ABSOLUTE ERROR : ",mae)
mse = mean_squared_error(y_test,d_pred)
print("MEAN SQUARED ERROR : ",mse)
# Out:
# R2 SCORE :  0.6893187873585522
# ROOT MEAN SQUARED ERROR :  0.5611497101273648
# MEAN ABSOLUTE ERROR :  0.413081084150986
# MEAN SQUARED ERROR :  0.3148889971760256

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
randomforest_model = RandomForestRegressor(n_estimators=100)
randomforest_model.fit(x_train,y_train)
r_pred = randomforest_model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
r2 = r2_score(y_test,r_pred)
print("R2 SCORE : ",r2) 
rms = root_mean_squared_error(y_test,r_pred)
print("ROOT MEAN SQUARED ERROR : ",rms)
mae = mean_absolute_error(y_test,r_pred)
print("MEAN ABSOLUTE ERROR : ",mae)
mse = mean_squared_error(y_test,r_pred)
print("MEAN SQUARED ERROR : ",mse)
# Out:
# R2 SCORE :  0.8266813099658937
# ROOT MEAN SQUARED ERROR :  0.4191253663680718
# MEAN ABSOLUTE ERROR :  0.3314405928651758
# MEAN SQUARED ERROR :  0.17566607273317042

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
g_model = GradientBoostingRegressor(n_estimators=100)
g_model.fit(x_train,y_train)
g_pred = g_model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
r2 = r2_score(y_test,g_pred)
print("R2 SCORE : ",r2)
rms = root_mean_squared_error(y_test,g_pred)
print("ROOT MEAN SQUARED ERROR : ",rms)
mae = mean_absolute_error(y_test,g_pred)
print("MEAN ABSOLUTE ERROR : ",mae)
mse = mean_squared_error(y_test,g_pred)
print("MEAN SQUARED ERROR : ",mse)
# Out:
# R2 SCORE :  0.8328628323026408
# ROOT MEAN SQUARED ERROR :  0.4115833202228074
# MEAN ABSOLUTE ERROR :  0.3260544597332131
# MEAN SQUARED ERROR :  0.16940082948563

# %%
import joblib
joblib.dump(g_model,'g_model.joblib')
# Out:
# ['g_model.joblib']
